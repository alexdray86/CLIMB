# %% [markdown]
# ## CLIMB Deconvolution - In-Vitro dataset
#
# CLIMB infers cell-subtype proportions through a linear combination of single-cell expression. By aggregating coefficients by cell subtype, it predicts the composition of a cell mix. We generated in vitro pools containing various ratios of HL60, SUDHL4, K562, and THP1 human leukemic cells. We use these pre-determined ratios as ground truth to assess the predictive value of CLIMB deconvolution.

# %%
library(climb) ; library(Biobase)

# %%
# METRICS FUNCTIONS
num <- function(x){ return(as.numeric(as.character(x))) }
rmse <- function(tr, pr){ return( sqrt( sum((tr - pr)^2) / length(tr) ) ) }
pcor <- function(tr, pr){ return( cor(tr, pr, method = 'pearson') ) }

# %% [markdown]
# ## Load data
#
# We load the data stored as `ExpressionSet` object (library `xbioc` required). We will load the scRNA-seq reference dataset in the object `sc.es` and the bulk RNA-seq from six mixtures in `bulk.es`.

# %%
# Load ExpressionSet object containing scRNA-seq data from in-vitro cell mixes
sc.es = readRDS("data/invitro_sc_es.RDS")
dim(sc.es)
# Out:
# Features  Samples
#     6169     2342

# %% [markdown]
# 2342 cells were sequenced and 6169 genes kept after filtering low counts with default Seurat pipeline

# %%
# Load ExpressionSet object containing bulk RNA-seq data from in-vitro cell mixes
bulk.es = readRDS("data/invitro_bulk_es.RDS")
dim(bulk.es)
# Out:
# Features  Samples
#     6169        6

# %% [markdown]
# 6 mixtures of cell lines with expression from 6169 genes

# %%
# Load True cell line proportions (based on the volume of homogeneised cells pippeted in the mixture)
true_prop = as.matrix(pData(bulk.es))
true_prop
# Out:
#       HL60   K562   SUDHL4 THP1
# BULK1 0.2600 0.0900 0.3300 0.3200
# BULK2 0.5700 0.1100 0.0700 0.2500
# BULK3 0.3333 0.2222 0.0000 0.4444
# BULK4 0.0500 0.0400 0.6100 0.3000
# BULK5 0.0198 0.3168 0.1881 0.4752
# BULK6 0.1200 0.2600 0.2000 0.4200

# %% [markdown]
# ### Functions

# %%
# METRICS FUNCTIONS
num <- function(x){ return(as.numeric(as.character(x))) }
mse <- function(tr, pr){ return( sum((tr - pr)^2) / length(tr) ) }
rmse <- function(tr, pr){ return( sqrt( sum((tr - pr)^2) / length(tr) ) ) }
scor <- function(tr, pr){ return( cor(tr, pr, method = 'spearman') ) }
pcor <- function(tr, pr){ return( cor(tr, pr, method = 'pearson') ) }
r_square <- function(pr, tr){
    SStot = sum((tr - mean(tr))^2)
    SSres = sum((pr - tr)^2)
    return(1 - SSres / SStot)
}

### Function to retrieve all metrics from Deconvolution vs True cell-type proportion comparison
comp_rows_and_cols <- function(pred_prop, true_prop){
    pc_l = list() ; sc_l = list()
    rsq_l = list(); rmse_l = list()
    for(i in 1:dim(pred_prop)[1]){
        pc_l[[i]] = cor(pred_prop[i,], true_prop[i,], method = 'pearson')
        sc_l[[i]] = cor(pred_prop[i,], true_prop[i,], method = 'spearman')
        rsq_l[[i]] = max(r_square(pred_prop[i,], true_prop[i,]), -1.0)
        rmse_l[[i]] = rmse(pred_prop[i,], true_prop[i,])
    }
    pc_c = list() ; sc_c = list()
    rsq_c = list(); rmse_c = list()
    for(i in 1:dim(pred_prop)[2]){
        pc_c[[i]] = cor(pred_prop[,i], true_prop[,i], method = 'pearson')
        sc_c[[i]] = cor(pred_prop[,i], true_prop[,i], method = 'spearman')
        rsq_c[[i]] = max(r_square(pred_prop[,i], true_prop[,i]), -1.0)
        rmse_c[[i]] = rmse(pred_prop[,i], true_prop[,i])
    }
    res = list() ; 
    res[[1]] = num(pc_l) ; res[[2]] = num(sc_l)
    res[[3]] = num(rsq_l); res[[4]] = num(rmse_l)
    res[[5]] = num(pc_c) ; res[[6]] = num(sc_c)
    res[[7]] = num(rsq_c); res[[8]] = num(rmse_c)
    res[[9]] = pcor(as.vector(num(pred_prop)), as.vector(num(true_prop)))
    res[[10]] = scor(as.vector(num(pred_prop)), as.vector(num(true_prop)))
    res[[11]] = max(r_square(as.vector(num(pred_prop)), as.vector(num(true_prop))), -1.0)
    res[[12]] = rmse(as.vector(num(pred_prop)), as.vector(num(true_prop)))
    return(res)
}

# %% [markdown]
# ## Study total expression

# %% [markdown]
# Now we want to get the size factors

# %%
srt.es = CreateSeuratObject(counts = exprs(sc.es))
srt.es <- SCTransform(srt.es, verbose = FALSE)

# %%
SRT_tot_expr = num(srt.es$nCount_SCT)
tot_expr = num(colSums(exprs(sc.es)))

# %%
plot(srt.es$nCount_RNA, srt.es$nCount_SCT)
# Out:
# plot without title

# %%
srt.es = CreateSeuratObject(counts = exprs(sc.es))

# %%
srt.es$tot_expr = tot_expr
srt.es$SCT_tot_expr = SRT_tot_expr

# %%
srt.es$cellType = sc.es$cellType

# %%
df_tot_expr = data.frame(cbind(srt.es$tot_expr, srt.es$SCT_tot_expr, sc.es$cellType))
colnames(df_tot_expr) = c('tot_RNA', 'srt_tot_RNA', 'cell_type')
scientific_10 <- function(x) {
  parse(text=gsub("e", " %*% 10^", scales::scientific_format()(x)))
}
df_tot_expr$cell_type = factor(df_tot_expr$cell_type, levels = c('K562', 'SUDHL4', 'THP1', 'HL60'))

# %%
options(repr.plot.width=5, repr.plot.height=2.5)
g <- ggplot(df_tot_expr) + geom_boxplot(aes(x=cell_type, y=num(tot_RNA))) +
    theme_classic() +scale_y_continuous(label=scientific_10) + 
    ylab('Total Expression per cell') + xlab('Cell Type') + coord_flip() +
pdf("results/invitro_total_expression.pdf", width=5, height=2.5) ; g ; dev.off()
g
# Out:
# pdf
#   2
# plot without title

# %%
sce <- SingleCellExperiment(list(counts=exprs(sc.es)),
                            colData=DataFrame(label=colnames(sc.es),
                                              cellType=sc.es$cellType,
                                              SubjectName=sc.es$SubjectName),
                            rowData=DataFrame(gene_name=rownames(sc.es)))

# %%
clusters <- quickCluster(sce)

# %%
sce <- computePooledFactors(sce, clusters=clusters)

# %% [markdown]
# ## CLIMB Deconvolution

# %%
### CLIMB/CLIMB-BA DECONVOLUTION FUNCTION ### 
climb_sce <- function(sc, bulk, ratio_cancer_cells=NA, up.lim=Inf, lambda=0, norm_factor=0.1){
# sc : ExpressionSet object containing the scRNA-seq reference dataset
# bulk : ExpressionSet object containing the mixtures to be deconvoluted
# ratio_cancer_cells : numeric vector, same size as number of mixtures. 
#     if we have data about the fraction of cancer cells present in mixture, this can improve deconvolution accuracy
#     If ratio_cancer_cells is provided, then CLIMB-BA method will be used. It is important that cancer cell-types in
#     the scRNA-seq dataset contains the pattern "-like" to be recognized as cancer cells.
# up.lim = Inf : numeric scalar, impose a l-infinity norm to the linear model (upper bound for coefficient)
# lambda = 0 : Regularization factor
# norm_factor = 0.1 ; if ratio_cancer_cells is provided, indicate strength of smooth normalization
    ct.props = list()
    sc.mat = as.matrix(counts(sc))
    N = dim(bulk)[2]
    cell_expr = num(sizeFactors(sc))
    for(i in 1:N){
        y = num(exprs(bulk)[,i])
        fit = glmnet(sc.mat, y, lower.limits = 0.0, upper.limits = up.lim, lambda = lambda)
        coefs = coef(fit)[-1,dim(coef(fit))[2]]
        norm_coefs = coefs / cell_expr # Normalize coefs with total expression per cell
        agg = aggregate(norm_coefs, list(sc$cellType), sum)
        # If information about cancer cell ratio is given, then a smooth normalization is done hereafter
        if(!is.na(sum(num(ratio_cancer_cells)))){
            colnames(agg) = c('celltype', 'sum_coefs')
            # Correct proportions with ratio cancer cells
            b_n = num(ratio_cancer_cells[i]) # True ratio cancer cells
            b_hat_n = sum(agg[grepl("-like",agg$celltype),]$sum_coefs) / sum(agg$sum_coefs) # predicted blast count
            # normalization factors
            f_n = (b_n + norm_factor) / (b_hat_n + norm_factor)
            f_n_n = (1 - b_n + norm_factor) / (1 - b_hat_n + norm_factor)
            agg_norm = agg
            agg_norm[grepl("-like",agg$celltype),]$sum_coefs <- agg_norm[grepl("-like",agg$celltype),]$sum_coefs * f_n
            agg_norm[!grepl("-like",agg$celltype),]$sum_coefs <- agg_norm[!grepl("-like",agg$celltype),]$sum_coefs * f_n_n
            agg_norm$sum_coefs = num(agg_norm$sum_coefs)
            agg_norm = agg_norm[match(levels(sc$cellType), agg_norm$celltype),]
            # Compute proportions and return results
            ppred = (agg_norm$sum_coefs) / sum(agg_norm$sum_coefs)
            ct.props[[i]] = ppred
        } else {
            ppred = (agg$x) / sum(agg$x)      
            names(ppred) = agg$`Group.1`
            ct.props[[i]] = ppred
        }
    }
    climb.prop = do.call(rbind,ct.props)
    return(as.matrix(climb.prop))
}

# %%
### CLIMB/CLIMB-BA DECONVOLUTION FUNCTION ### 
climb_srt <- function(sc, bulk, ratio_cancer_cells=NA, up.lim=Inf, lambda=0, norm_factor=0.1){
# sc : ExpressionSet object containing the scRNA-seq reference dataset
# bulk : ExpressionSet object containing the mixtures to be deconvoluted
# ratio_cancer_cells : numeric vector, same size as number of mixtures. 
#     if we have data about the fraction of cancer cells present in mixture, this can improve deconvolution accuracy
#     If ratio_cancer_cells is provided, then CLIMB-BA method will be used. It is important that cancer cell-types in
#     the scRNA-seq dataset contains the pattern "-like" to be recognized as cancer cells.
# up.lim = Inf : numeric scalar, impose a l-infinity norm to the linear model (upper bound for coefficient)
# lambda = 0 : Regularization factor
# norm_factor = 0.1 ; if ratio_cancer_cells is provided, indicate strength of smooth normalization
    ct.props = list()
    sc.mat = as.matrix(GetAssayData(object = sc, slot = "counts"))
    N = dim(bulk)[2]
    cell_expr = num(sc$SCT_tot_expr)
    for(i in 1:N){
        y = num(exprs(bulk)[,i])
        fit = glmnet(sc.mat, y, lower.limits = 0.0, upper.limits = up.lim, lambda = lambda)
        coefs = coef(fit)[-1,dim(coef(fit))[2]]
        norm_coefs = coefs / cell_expr # Normalize coefs with total expression per cell
        agg = aggregate(norm_coefs, list(sc$cellType), sum)
        # If information about cancer cell ratio is given, then a smooth normalization is done hereafter
        if(!is.na(sum(num(ratio_cancer_cells)))){
            colnames(agg) = c('celltype', 'sum_coefs')
            # Correct proportions with ratio cancer cells
            b_n = num(ratio_cancer_cells[i]) # True ratio cancer cells
            b_hat_n = sum(agg[grepl("-like",agg$celltype),]$sum_coefs) / sum(agg$sum_coefs) # predicted blast count
            # normalization factors
            f_n = (b_n + norm_factor) / (b_hat_n + norm_factor)
            f_n_n = (1 - b_n + norm_factor) / (1 - b_hat_n + norm_factor)
            agg_norm = agg
            agg_norm[grepl("-like",agg$celltype),]$sum_coefs <- agg_norm[grepl("-like",agg$celltype),]$sum_coefs * f_n
            agg_norm[!grepl("-like",agg$celltype),]$sum_coefs <- agg_norm[!grepl("-like",agg$celltype),]$sum_coefs * f_n_n
            agg_norm$sum_coefs = num(agg_norm$sum_coefs)
            agg_norm = agg_norm[match(levels(sc$cellType), agg_norm$celltype),]
            # Compute proportions and return results
            ppred = (agg_norm$sum_coefs) / sum(agg_norm$sum_coefs)
            ct.props[[i]] = ppred
        } else {
            ppred = (agg$x) / sum(agg$x)      
            names(ppred) = agg$`Group.1`
            ct.props[[i]] = ppred
        }
    }
    climb.prop = do.call(rbind,ct.props)
    return(as.matrix(climb.prop))
}

# %%
### CLIMB/CLIMB-BA DECONVOLUTION FUNCTION ### 
climb <- function(sc, bulk, ratio_cancer_cells=NA, up.lim=Inf, lambda=0, norm_factor=0.1){
# sc : ExpressionSet object containing the scRNA-seq reference dataset
# bulk : ExpressionSet object containing the mixtures to be deconvoluted
# ratio_cancer_cells : numeric vector, same size as number of mixtures. 
#     if we have data about the fraction of cancer cells present in mixture, this can improve deconvolution accuracy
#     If ratio_cancer_cells is provided, then CLIMB-BA method will be used. It is important that cancer cell-types in
#     the scRNA-seq dataset contains the pattern "-like" to be recognized as cancer cells.
# up.lim = Inf : numeric scalar, impose a l-infinity norm to the linear model (upper bound for coefficient)
# lambda = 0 : Regularization factor
# norm_factor = 0.1 ; if ratio_cancer_cells is provided, indicate strength of smooth normalization
    ct.props = list()
    sc.mat = exprs(sc)
    N = dim(bulk)[2]
    cell_expr = colSums(exprs(sc))
    for(i in 1:N){
        y = num(exprs(bulk)[,i])
        fit = glmnet(sc.mat, y, lower.limits = 0.0, upper.limits = up.lim, lambda = lambda)
        coefs = coef(fit)[-1,dim(coef(fit))[2]]
        norm_coefs = coefs / cell_expr # Normalize coefs with total expression per cell
        agg = aggregate(norm_coefs, list(sc$cellType), sum)
        # If information about cancer cell ratio is given, then a smooth normalization is done hereafter
        if(!is.na(sum(num(ratio_cancer_cells)))){
            colnames(agg) = c('celltype', 'sum_coefs')
            # Correct proportions with ratio cancer cells
            b_n = num(ratio_cancer_cells[i]) # True ratio cancer cells
            b_hat_n = sum(agg[grepl("-like",agg$celltype),]$sum_coefs) / sum(agg$sum_coefs) # predicted blast count
            # normalization factors
            f_n = (b_n + norm_factor) / (b_hat_n + norm_factor)
            f_n_n = (1 - b_n + norm_factor) / (1 - b_hat_n + norm_factor)
            agg_norm = agg
            agg_norm[grepl("-like",agg$celltype),]$sum_coefs <- agg_norm[grepl("-like",agg$celltype),]$sum_coefs * f_n
            agg_norm[!grepl("-like",agg$celltype),]$sum_coefs <- agg_norm[!grepl("-like",agg$celltype),]$sum_coefs * f_n_n
            agg_norm$sum_coefs = num(agg_norm$sum_coefs)
            agg_norm = agg_norm[match(levels(sc$cellType), agg_norm$celltype),]
            # Compute proportions and return results
            ppred = (agg_norm$sum_coefs) / sum(agg_norm$sum_coefs)
            ct.props[[i]] = ppred
        } else {
            ppred = (agg$x) / sum(agg$x)      
            names(ppred) = agg$`Group.1`
            ct.props[[i]] = ppred
        }
    }
    climb.prop = do.call(rbind,ct.props)
    return(as.matrix(climb.prop))
}

# %%
climb_sce_prop = climb_sce(sce, bulk.es)

# %%
climb_srt_prop = climb_srt(srt.es, bulk.es)

# %%
climb_totExpr_prop = climb(sc.es, bulk.es)

# %%
climb_noNorm_prop = climb(sc.es, bulk.es)

# %%
# Display the Pearson correlation coefficient considering all 24 dots (6 mixtures with 4 cell lines)
cor(as.vector(as.matrix(true_prop)), as.vector(as.matrix(climb_totExpr_prop)))
# Out:
# [1] 0.9428949

# %%
sc.mat = exprs(sc.es)

# %%
y = num(exprs(bulk.es)[,1])

# %%
# Plot and display the results 
options(repr.plot.width=4, repr.plot.height=3)
df_cor = cbind(reshape2::melt(data.frame(true_prop)), 
               reshape2::melt(data.frame(climb_sce_prop)))
colnames(df_cor) = c('cell line', 'True Proportions', 'x', 'CLIMB predictions')
g = ggplot(df_cor) + geom_abline(slope=1, linetype = "dashed", colour='cornflowerblue') + 
    geom_point(aes(y=`True Proportions`, x=`CLIMB predictions`, colour=`cell line`), size=3) + theme_classic2() + 
    scale_color_manual(values=c('navajowhite2',  'darkred', 'seagreen', 'grey58')) +
    ylab('True Proportions') + xlab('CLIMB predictions')
pdf("results/invitro_CLIMB_SCEnorm_deconvolution.pdf", width=5, height=4) ; g ; dev.off()
g
# Out:
# No id variables; using all as measure variables
#
# No id variables; using all as measure variables
# pdf
#   2
# plot without title

# %%
rmse(as.vector(true_prop), as.vector(climb_totExpr_prop))
# Out:
# [1] 0.05628396

# %%
climb.totExpr.res = comp_rows_and_cols(climb_totExpr_prop, true_prop)
climb.sce.res = comp_rows_and_cols(climb_sce_prop, true_prop)
climb.srt.res = comp_rows_and_cols(climb_srt_prop, true_prop)
climb.noNorm.res = comp_rows_and_cols(climb_noNorm_prop, true_prop)

# %%
climb.sce.res[[12]]
# Out:
# [1] 0.05669963

# %%
climb.totExpr.res[[12]]
# Out:
# [1] 0.05628396

# %%
df_mean_prop = do.call(rbind,list(colMeans(true_prop),colMeans(climb_totExpr_prop),colMeans(climb_noNorm_prop),
                                  colMeans(bayesprism_prop), colMeans(music_prop), colMeans(csx_prop)))
rownames(df_mean_prop) = c('TrueProp', 'CLIMB-NormTotExpr', 'CLIMB-NoNorm', 'BayesPrism', 'MUSIC', 'CiberSortX')
melt_mean_prop = melt(df_mean_prop)
colnames(melt_mean_prop) = c('Method', 'Cell Type', 'prop')
melt_mean_prop$`Cell Type` = factor(melt_mean_prop$`Cell Type`, levels=rev(c('K562', 'THP1', 'SUDHL4', 'HL60')))

# %%
options(repr.plot.width=6, repr.plot.height=3)
g <- ggplot(melt_mean_prop, aes(y=Method, x=num(prop), fill=`Cell Type`)) + 
    geom_bar(position="fill", stat="identity") + theme_minimal() +
    scale_fill_manual(values = c('navajowhite2', 'seagreen', 'grey58', 'darkred')) +
    xlab('Cell Type Proportions') + ylab('')
pdf("results/invitro_average_cell_type_prop.pdf", width=6, height=3) ; g ; dev.off()
g
# Out:
# pdf
#   2
# plot without title

# %%
rbind(colMeans(true_prop),colMeans(climb_totExpr_prop),colMeans(climb.noNorm.res))
# Out:
# Error in base::colMeans(x, na.rm = na.rm, dims = dims, ...): 'x' must be an array of at least two dimensions
# Traceback:
#
# 1. rbind(colMeans(true_prop), colMeans(climb_totExpr_prop), colMeans(climb.noNorm.res))
# 2. standardGeneric("rbind")
# 3. eval(quote(list(...)), env)
# 4. eval(quote(list(...)), env)
# 5. eval(quote(list(...)), env)
# 6. colMeans(climb.noNorm.res)
# 7. colMeans(climb.noNorm.res)
# 8. base::colMeans(x, na.rm = na.rm, dims = dims, ...)
# 9. stop("'x' must be an array of at least two dimensions")

# %% [markdown]
# ## BayesPrism Deconvolution

# %%
myPrism <- new.prism(reference= t(exprs(sc.es)), 
                     mixture=t(exprs(bulk.es)), input.type="count.matrix", 
                     cell.type.labels = as.character(sc.es$cellType), 
                     cell.state.labels = as.character(sc.es$cellType), 
                     key = NULL,outlier.cut=0.01,outlier.fraction=0.1,
)
# Out:
# number of cells in each cell state
# cell.state.labels
# SUDHL4   THP1   HL60   K562
#    551    562    570    659
# No tumor reference is speficied. Reference cell types are treated equally.
# Number of outlier genes filtered from mixture = 3
# Aligning reference and mixture...
# Nornalizing reference...

# %%
bp.res <- run.prism(prism = myPrism, n.cores=6)
# Out:
# Run Gibbs sampling...
# Current time:  2022-11-16 11:18:16
# Estimated time to complete:  2mins
# Estimated finishing time:  2022-11-16 11:20:16
# Start run...
# R Version:  R version 4.2.2 (2022-10-31)
# snowfall 1.84-6.2 initialized (using snow 0.4-4): parallel execution on 6 CPUs.
#
#
#
# Stopping cluster
# Update the reference matrix ...
# snowfall 1.84-6.2 initialized (using snow 0.4-4): parallel execution on 6 CPUs.
#
#
#
# Stopping cluster
# Run Gibbs sampling using updated reference ...
# Current time:  2022-11-16 11:19:48
# Estimated time to complete:  2mins
# Estimated finishing time:  2022-11-16 11:21:12
# Start run...
# snowfall 1.84-6.2 initialized (using snow 0.4-4): parallel execution on 6 CPUs.
#
#
#
# Stopping cluster

# %%
bayesprism_prop <- get.fraction (bp=bp.res, which.theta="final",
             state.or.type="type")
bayesprism_prop = bayesprism_prop[,match(colnames(true_prop), colnames(bayesprism_prop))]
bayesprism_prop
# Out:
#       HL60       K562         SUDHL4     THP1
# BULK1 0.37607119 3.335843e-02 0.37831383 0.2122566
# BULK2 0.68756631 2.014693e-03 0.16017785 0.1502411
# BULK3 0.45129727 1.647665e-01 0.07551986 0.3084163
# BULK4 0.02739875 8.448482e-06 0.76029153 0.2123013
# BULK5 0.07428679 2.710350e-01 0.33105103 0.3236272
# BULK6 0.18381648 2.599649e-01 0.31313763 0.2430810

# %%
# Display the Pearson correlation coefficient considering all 24 dots (6 mixtures with 4 cell lines)
cor(as.vector(true_prop), as.vector(bayesprism_prop))
# Out:
# [1] 0.8466672

# %%
df_msc = cbind(reshape2::melt(data.frame(true_prop)), 
               reshape2::melt(data.frame(bayesprism_prop)))
colnames(df_msc) = c('cell_line', 'true.prop', 'x', 'bayesprism_prop')
options(repr.plot.width=5, repr.plot.height=4)
g = ggplot(df_msc) + geom_abline(slope=1, linetype = "dashed", colour='cornflowerblue') + 
    geom_point(aes(x=true.prop, y=bayesprism_prop, colour=cell_line)) + theme_classic2() + 
    scale_color_manual(values=c('navajowhite2',  'darkred', 'seagreen', 'grey58')) +
    ylab('True Proportions') + xlab('BayesPrism predictions')
#pdf("results/invitro_2d_BayesPrism_deconvolution.pdf", width=5, height=4) ; g ; dev.off()
g
# Out:
# No id variables; using all as measure variables
#
# No id variables; using all as measure variables
# plot without title

# %%
bayesprism.res = comp_rows_and_cols(bayesprism_prop, true_prop)

# %% [markdown]
# ## MuSiC Deconvolution

# %%
sce <- SingleCellExperiment(list(counts=exprs(sc.es)),
                            colData=DataFrame(label=colnames(sc.es),
                                              cellType=sc.es$cellType,
                                              SubjectName=sc.es$SubjectName),
                            rowData=DataFrame(gene_name=rownames(sc.es))
                            )
sce

# Estimate cell type proportions
music.output = music_prop(bulk.mtx = exprs(bulk.es), 
                             sc.sce = sce, 
                             clusters = 'cellType',
                             samples = 'SubjectName',
                             verbose = T)
music_prop = music.output$Est.prop.weighted
# Out:
# class: SingleCellExperiment
# dim: 6169 2342
# metadata(0):
# assays(1): counts
# rownames(6169): AAK1 AAMP ... ZZEF1 ZZZ3
# rowData names(1): gene_name
# colnames(2342): AAACAGCCACCGGCTA AAACCAACACCCACAG ... TTTGTTGGTCCTAACT
#   TTTGTTGGTTAGGACC
# colData names(3): label cellType SubjectName
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):

# %%
# Estimate cell type proportions
music.output = music_prop(bulk.mtx = exprs(bulk.es), 
                             sc.sce = sce, 
                             clusters = 'cellType',
                             samples = 'SubjectName',
                             verbose = T)
music_prop = music.output$Est.prop.weighted
# Out:
# Creating Relative Abudance Matrix...
#
# Creating Variance Matrix...
#
# Creating Library Size Matrix...
#
# Used 6169 common genes...
#
# Used 4 cell types in deconvolution...
#
# BULK1 has common genes 6164 ...
#
# BULK2 has common genes 6166 ...
#
# BULK3 has common genes 6143 ...
#
# BULK4 has common genes 6107 ...
#
# BULK5 has common genes 6158 ...
#
# BULK6 has common genes 6167 ...

# %%
music_prop = music_prop[,match(colnames(true_prop), colnames(music_prop))]

# %%
cor(as.vector(music_prop), as.vector(true_prop))
# Out:
# [1] 0.7514244

# %%
df_msc = cbind(reshape2::melt(data.frame(true_prop)), 
               reshape2::melt(data.frame(music_prop)))

colnames(df_msc) = c('cell_line', 'true.prop', 'x', 'MuSiC.prop')
# Out:
# No id variables; using all as measure variables
#
# No id variables; using all as measure variables

# %%
g = ggplot(df_msc) + geom_abline(slope=1, linetype = "dashed", colour='cornflowerblue') + 
    geom_point(aes(y=true.prop, x=MuSiC.prop, colour=cell_line)) + theme_classic2() + 
    scale_color_manual(values=c('navajowhite2',  'darkred', 'seagreen', 'grey58')) +
    ylab('True Proportions') + xlab('MuSiC predictions')
#pdf("results/invitro_2d_MUSIC_deconvolution.pdf", width=5, height=4) ; g ; dev.off()
g
# Out:
# plot without title

# %%
# Save results with all metrics
music.res = comp_rows_and_cols(music_prop, true_prop)

# %% [markdown]
# ### NNLS Deconvolution

# %%
# NNLS estimation is found in the output of MUSIC deconvolution 
nnls_prop = music.output$Est.prop.allgene
nnls_prop = nnls_prop[,match(colnames(true_prop), colnames(nnls_prop))]

# %%
cor(as.vector(nnls_prop), as.vector(true_prop))
# Out:
# [1] -0.03215152

# %%
# Save results with all metrics
nnls.res = comp_rows_and_cols(nnls_prop, true_prop)
# Out:
# Warning message in cor(pred_prop[, i], true_prop[, i], method = "pearson"):
# “the standard deviation is zero”
# Warning message in cor(pred_prop[, i], true_prop[, i], method = "spearman"):
# “the standard deviation is zero”
# Warning message in cor(pred_prop[, i], true_prop[, i], method = "pearson"):
# “the standard deviation is zero”
# Warning message in cor(pred_prop[, i], true_prop[, i], method = "spearman"):
# “the standard deviation is zero”
# Warning message in num(pc_c):
# “NAs introduced by coercion”
# Warning message in num(sc_c):
# “NAs introduced by coercion”

# %% [markdown]
# ### BisqueRNA

# %%
bisqueRNA_fun <- function(sc, bulk){
    # Launch BisqueRNA
    bisque.res = BisqueRNA::ReferenceBasedDecomposition(bulk, sc, use.overlap=F)

    # Get back cell type proportion and arrange them is right order
    res.prop = data.frame(t(bisque.res$bulk.props))

    return(as.matrix(res.prop))
}

# %%
bisque_prop = bisqueRNA_fun(sc.es, bulk.es)
# Out:
# Decomposing into 4 cell types.
#
# Using 6169 genes in both bulk and single-cell expression.
#
# Converting single-cell counts to CPM and filtering zero variance genes.
#
# Filtered 0 zero variance genes.
#
# Converting bulk counts to CPM and filtering unexpressed genes.
#
# Filtered 0 unexpressed genes.
#
# Generating single-cell based reference from 2342 cells.
#
#
# Inferring bulk transformation from single-cell alone.
#
# Applying transformation to bulk samples and decomposing.

# %%
all(colnames(bisque_prop) == colnames(true_prop))
# Out:
# [1] TRUE

# %%
# Display the Pearson correlation coefficient considering all 24 dots (6 mixtures with 4 cell lines)
cor(as.vector(as.matrix(true_prop)), as.vector(as.matrix(bisque_prop)))
# Out:
# [1] 0.02402223

# %%
df_cor = cbind(reshape2::melt(data.frame(true_prop)), 
               reshape2::melt(data.frame(bisque_prop[1:6,])))
colnames(df_cor) = c('cell_line', 'true.prop', 'x', 'Bisque.pred')
g = ggplot(df_cor) + geom_abline(slope=1, linetype = "dashed", colour='cornflowerblue') + 
    geom_point(aes(y=true.prop, x=Bisque.pred, colour=cell_line)) + theme_classic2() + 
    scale_color_manual(values=c('navajowhite2',  'darkred', 'seagreen', 'grey58')) +
    ylab('True Proportions') + xlab('BisqueRNA predictions')
#pdf("figs/BISQUE_vs_true_prop_2ddot_AllG.pdf", width=5, height=4) ; g ; dev.off()
g
# Out:
# No id variables; using all as measure variables
#
# No id variables; using all as measure variables
# plot without title

# %%
bisque.res = comp_rows_and_cols(bisque_prop, true_prop)

# %% [markdown]
# ## CiberSortX Deconvolution
#
# As CSX is not offering a R library, we show here how we built the tables used on their website, and the show the figures obtained from the ouput.

# %%
# The following code was used to write tables that were used to run CiberSortX on their website interface
# Uncomment following lines to run it :
#sc_mat = exprs(sc.es)
#colnames(sc_mat) = as.character(sc.es$cellType) # cell-type labels provided as column names
#write.table(sc_mat , "data/sc_mat_invitro.txt", sep = '\t', quote=F)
#write.table(exprs(bulk.es), "data/pbulks_invitro.txt", sep = '\t', quote=F)

# %%
# We load the processed tables
csx_prop = read.csv("data/invitro_tables/cibersortx_prop.csv", row.names = "Mixture")
csx_prop = csx_prop[,seq(1,4)]
csx_prop = as.matrix(csx_prop[,match(colnames(true_prop), colnames(csx_prop))])
# Display PCC for 24 dots all together
cor(as.vector(csx_prop), as.vector(true_prop))
# Out:
# [1] 0.7308551

# %%
df_msc = cbind(reshape2::melt(data.frame(true_prop)), 
               reshape2::melt(data.frame(csx_prop)))
colnames(df_msc) = c('cell_line', 'true.prop', 'x', 'csx_props')
g = ggplot(df_msc) + geom_abline(slope=1, linetype = "dashed", colour='cornflowerblue') + 
    geom_point(aes(y=true.prop, x=csx_props, colour=cell_line)) + theme_classic2() + 
    scale_color_manual(values=c('navajowhite2',  'darkred', 'seagreen', 'grey58')) +
    ylab('True Proportions') + xlab('CiberSortX predictions')
#pdf("results/invitro/figs/CiberSortX_vs_true_prop_2ddot_AllG.pdf", width=5, height=4) ; g ; dev.off()
g
# Out:
# No id variables; using all as measure variables
#
# No id variables; using all as measure variables
# plot without title

# %%
csx.res = comp_rows_and_cols(csx_prop, true_prop)

# %% [markdown]
# ## Negative Control : Random cell-type proportions

# %%
rand_prop = matrix(rnorm(24),nrow=6)
rand_prop = rand_prop - min(rand_prop) ; rand_prop = rand_prop / rowSums(rand_prop)
colnames(rand_prop) = colnames(true_prop) ; rownames(rand_prop) = rownames(true_prop)
rand.res = comp_rows_and_cols(rand_prop, as.matrix(true_prop))

# %% [markdown]
# ## Load pre-processed Deconvolution results
#
# Here is the results of diverse deconvolution methods, to be loaded to reproduce same results as in the manuscripts, and to be compared with results obtained above.

# %%
# If one need to load pre-processed deconvolution resoluts, just uncomment the ones needed : 
# CiberSortX
#csx_prop = read.csv("data/invitro_tables/cibersortx_prop.csv", row.names = "Mixture")
#csx_prop = csx_prop[,seq(1,4)]
#csx_prop = as.matrix(csx_prop[,match(colnames(true_prop), colnames(csx_prop))])
#csx.res = comp_rows_and_cols(csx_prop, true_prop)

# BayesPrism
#bayesprism_prop = as.matrix(read.csv("data/invitro_tables/bayesprism_prop.csv", row.names = 'X'))
#bayesprism.res = comp_rows_and_cols(bayesprism_prop, true_prop)

# MUSIC
#music_prop = as.matrix(read.csv("data/invitro_tables/music_prop.csv", row.names = 'X'))
#music.res = comp_rows_and_cols(music_prop, true_prop)

# NNLS
#nnls_prop = as.matrix(read.csv("data/invitro_tables/nnls_prop.csv", row.names = 'X'))
#nnls.res = comp_rows_and_cols(nnls_prop, true_prop)

# BisqueRNA
#bisque_prop = as.matrix(read.csv("data/invitro_tables/bisque_prop.csv", row.names = 'X'))
#bisque.res = comp_rows_and_cols(bisque_prop, true_prop)

# %% [markdown]
# ## Plot the comparative results

# %%
# Change the Metric by setting type.err to 1, 2, 3, or 4
type.err = 4 # 1=pcor, 2=scor, 3=r_square, 4=rmse
type.err.l = list('PCC', 'SCC', 'R2', 'RMSE')
df_scor = data.frame(cbind(music.res[[type.err]], #nnls.res[[type.err]], 
                           climb.totExpr.res[[type.err]], climb.noNorm.res[[type.err]], climb.sce.res[[type.err]],climb.srt.res[[type.err]],
                           bisque.res[[type.err]], rand.res[[type.err]], bayesprism.res[[type.err]], csx.res[[type.err]]))
colnames(df_scor) = c('MuSiC', 'CLIMB-NormTotRNA', 'CLIMB-NoNorm', 'CLIMB-SCEnorm','CLIMB-SeuratNorm','Bisque', 'Random', 'BayesPrism', 'CiberSortX') #'CLIMB-SCE.SizeFactors', 'CLIMB-SCT.SizeFactors', 
df_scor_m = reshape2::melt(df_scor)
df_scor_m$variable = factor(df_scor_m$variable, levels = c('CLIMB-NormTotRNA', 'CLIMB-SCEnorm','CLIMB-SeuratNorm','CLIMB-NoNorm', 'BayesPrism', 'CiberSortX','MuSiC', 'Bisque',  'Random')) #'CLIMB-SCE.SizeFactors', 'CLIMB-SCT.SizeFactors', 

options(repr.plot.width=3, repr.plot.height=3)
g_rows = ggplot(df_scor_m) + geom_boxplot(aes(x=variable, y=value, color=variable), outlier.shape = NA) + theme_classic() +
            geom_jitter(aes(x=variable, y=value, color=variable)) + theme_classic() +
            scale_color_manual(values=c('darkred','darkred','darkred','darkred','grey28','grey28','grey28','grey28','grey28','grey28')) + 
            theme(legend.position="none", axis.text.x = element_text(angle = 0, hjust=0.5, vjust=1.0)) +
            xlab('') + ylab(type.err.l[type.err]) + coord_flip() # ylab(expression(paste(rho,' spearman'))) ylab(expression(R[2]))


df_scor = data.frame(cbind(music.res[[type.err+4]], #nnls.res[[type.err+4]], 
                           climb.totExpr.res[[type.err+4]], climb.noNorm.res[[type.err+4]], climb.sce.res[[type.err+4]],climb.srt.res[[type.err+4]],
                           bisque.res[[type.err+4]], rand.res[[type.err+4]], bayesprism.res[[type.err+4]], csx.res[[type.err+4]]))
colnames(df_scor) = c('MuSiC', 'CLIMB-NormTotRNA', 'CLIMB-NoNorm', 'CLIMB-SCEnorm','CLIMB-SeuratNorm','Bisque', 'Random', 'BayesPrism', 'CiberSortX') #'CLIMB-SCE.SizeFactors', 'CLIMB-SCT.SizeFactors', 
df_scor_m = reshape2::melt(df_scor)
df_scor_m$variable = factor(df_scor_m$variable, levels = c('CLIMB-NormTotRNA', 'CLIMB-SCEnorm','CLIMB-SeuratNorm','CLIMB-NoNorm', 'BayesPrism', 'CiberSortX','MuSiC', 'Bisque',  'Random')) #'CLIMB-SCE.SizeFactors', 'CLIMB-SCT.SizeFactors', 

g_cols = ggplot(df_scor_m) + geom_boxplot(aes(x=variable, y=value, color=variable), outlier.shape = NA) + theme_classic() +
            geom_jitter(aes(x=variable, y=value, color=variable)) + theme_classic() +
            scale_color_manual(values=c('darkred','darkred','darkred','darkred','grey28','grey28','grey28','grey28','grey28','grey28')) + 
            theme(legend.position="none", axis.text.x = element_text(angle = 0, hjust=0.5, vjust=1.0)) +
            xlab('') + ylab(type.err.l[type.err])+ coord_flip() # paste(rho,' spearman')

df_scor = data.frame(cbind(music.res[[type.err+8]], #nnls.res[[type.err+8]], 
                           climb.totExpr.res[[type.err+8]], climb.noNorm.res[[type.err+8]], climb.sce.res[[type.err]],climb.srt.res[[type.err]],
                           bisque.res[[type.err+8]], rand.res[[type.err+8]], bayesprism.res[[type.err+8]], csx.res[[type.err+8]]))
colnames(df_scor) = c('MuSiC',  'CLIMB-NormTotRNA', 'CLIMB-NoNorm', 'CLIMB-SCEnorm','CLIMB-SeuratNorm','Bisque', 'Random', 'BayesPrism', 'CiberSortX') #'CLIMB-SCE.SizeFactors', 'CLIMB-SCT.SizeFactors', 
df_scor_m = reshape2::melt(df_scor)
df_scor_m = aggregate(df_scor_m$value, by=list(df_scor_m$variable), mean)
colnames(df_scor_m) = c('variable', 'value')
df_scor_m$variable = factor(df_scor_m$variable, levels = c('CLIMB-NormTotRNA', 'CLIMB-SCEnorm','CLIMB-SeuratNorm','CLIMB-NoNorm',  'BayesPrism', 'CiberSortX','MuSiC', 'Bisque', 'Random')) #'CLIMB-SCE.SizeFactors', 'CLIMB-SCT.SizeFactors', 

g_bar = ggplot(df_scor_m) + geom_bar(aes(x=variable, y=value, fill=variable), stat="identity") + theme_classic() +
            scale_fill_manual(values=c('darkred','darkred','darkred','darkred','grey28','grey28','grey28','grey28','grey28','grey28')) + 
            theme(legend.position="none", axis.text.x = element_text(angle = 0, hjust=0.5, vjust=1.0)) +
            xlab('') + ylab(type.err.l[type.err])+ coord_flip() #+ scale_y_continuous(breaks=seq(-0.2,1.1,0.1))

# Display figures:
#g_cols
#g_rows
#g_bar
# Out:
# No id variables; using all as measure variables
#
# No id variables; using all as measure variables
#
# No id variables; using all as measure variables

# %%
climb.totExpr.res[[type.err+8]]
# Out:
# [1] 0.05628396

# %%
options(repr.plot.width=5, repr.plot.height=6)
g_arr = ggarrange(g_bar, g_rows, g_cols, ncol = 1, nrow = 3)
pdf("results/CLIMB_NORMs_boxplot_compMethods_RMSE.pdf", width=5, height=6) ; g_arr ; dev.off()
g_arr
# Out:
# pdf
#   2
# plot without title
